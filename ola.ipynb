# %% [markdown]
# # OLA RIDE INSIGHTS

# %%
# Reading the excel file

import pandas as pd
path = r"C:\Users\gopir\Desktop\ola\Data\OLA_DataSet.xlsx"
df = pd.read_excel(path)
df
# Out:
#                       Date      Time     Booking_ID        Booking_Status  \
# 0      2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1      2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2      2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3      2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4      2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                    ...       ...            ...                   ...
# 103019 2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020 2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021 2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022 2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023 2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# ...

# %%
# finding null values

df.isna().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer    92525
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# Vehicle Images                    0
# dtype: int64

# %%
# information about data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[ns]
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   object
#  11  Canceled_Rides_by_Driver    18434 non-null   object
# ...

# %%
# checking for duplicate values in data

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# finding min, max, avg of data columns
df.describe()
# Out:
#                                 Date         V_TAT         C_TAT  \
# count                         103024  63967.000000  63967.000000
# mean   2024-07-16 11:31:38.879678720    170.876952     84.873372
# min              2024-07-01 00:00:00     35.000000     25.000000
# 25%              2024-07-08 18:41:00     98.000000     55.000000
# 50%              2024-07-16 11:23:00    168.000000     85.000000
# 75%              2024-07-24 05:18:00    238.000000    115.000000
# max              2024-07-31 23:58:00    308.000000    145.000000
# std                              NaN     80.803640     36.005100
#
#        Booking_Value  Ride_Distance  Driver_Ratings  Customer_Rating
# count  103024.000000  103024.000000    63967.000000     63967.000000
# mean      548.751883      14.189927        3.997457         3.998313
# min       100.000000       0.000000        3.000000         3.000000
# 25%       242.000000       0.000000        3.500000         3.500000
# ...

# %%
# to view the columns
df.columns
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images'],
#       dtype='object')

# %%
# unique values count

print(df[['Booking_ID', 'Booking_Status', 'Customer_ID','Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT','Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver','Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value','Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating']].nunique())
# Out:
# Booking_ID                    103024
# Booking_Status                     4
# Customer_ID                    94544
# Vehicle_Type                       7
# Pickup_Location                   50
# Drop_Location                     50
# V_TAT                             40
# C_TAT                             25
# Canceled_Rides_by_Customer         5
# Canceled_Rides_by_Driver           4
# Incomplete_Rides                   2
# Incomplete_Rides_Reason            3
# Booking_Value                   2883
# Payment_Method                     4
# Ride_Distance                     50
# Driver_Ratings                    21
# Customer_Rating                   21
# dtype: int64

# %%
# booking status reasons

print(df['Booking_Status'].value_counts())
# Out:
# Booking_Status
# Success                 63967
# Canceled by Driver      18434
# Canceled by Customer    10499
# Driver Not Found        10124
# Name: count, dtype: int64

# %%
# different type of vehicles used
print(df['Vehicle_Type'].value_counts())
# Out:
# Vehicle_Type
# Prime Sedan    14877
# eBike          14816
# Auto           14755
# Prime Plus     14707
# Bike           14662
# Prime SUV      14655
# Mini           14552
# Name: count, dtype: int64

# %%
# unique type of payments customer made
print(df['Payment_Method'].value_counts())
# Out:
# Payment_Method
# Cash           35022
# UPI            25881
# Credit Card     2435
# Debit Card       629
# Name: count, dtype: int64

# %%
# check whether incomplete rides reason is because of incomplete bookings & how many bookings it is like that

df[df['Incomplete_Rides_Reason'].isnull()]['Booking_Status'].value_counts()

#Most of the 39,057 missing values in columns like V_TAT, C_TAT, Driver_Ratings, Payment_Method, etc., line up exactly with non-successful bookings.
#So, those values are only present for successful rides, and missing for canceled/incomplete ones.
#These nulls are not missing at random—they're missing by design
#So, Keeping the Missing Values As-Is for analysis
# Out:
# Booking_Status
# Success                 60041
# Canceled by Driver      18434
# Canceled by Customer    10499
# Driver Not Found        10124
# Name: count, dtype: int64

# %%
# to find correlation

df.corr(numeric_only=True)
# Out:
#                     V_TAT     C_TAT  Booking_Value  Ride_Distance  \
# V_TAT            1.000000  0.000249      -0.003671      -0.011204
# C_TAT            0.000249  1.000000      -0.004443       0.000074
# Booking_Value   -0.003671 -0.004443       1.000000       0.000492
# Ride_Distance   -0.011204  0.000074       0.000492       1.000000
# Driver_Ratings  -0.002300 -0.002815      -0.001327      -0.007235
# Customer_Rating  0.000574  0.001015       0.006231       0.009871
#
#                  Driver_Ratings  Customer_Rating
# V_TAT                 -0.002300         0.000574
# C_TAT                 -0.002815         0.001015
# Booking_Value         -0.001327         0.006231
# Ride_Distance         -0.007235         0.009871
# Driver_Ratings         1.000000        -0.002807
# Customer_Rating       -0.002807         1.000000

# %%
#Getting the proportion of the values

df['Booking_Status'].value_counts(normalize=True) * 100
# Out:
# Booking_Status
# Success                 62.089416
# Canceled by Driver      17.892918
# Canceled by Customer    10.190829
# Driver Not Found         9.826836
# Name: proportion, dtype: float64

# %%
#Getting proportion of payment values
df['Payment_Method'].value_counts(normalize=True) * 100
# Out:
# Payment_Method
# Cash           54.750106
# UPI            40.459925
# Credit Card     3.806650
# Debit Card      0.983320
# Name: proportion, dtype: float64

# %%
# Booking Status Distribution - Bar diagram

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime


plt.figure(figsize=(8, 6))
sns.countplot(x='Booking_Status', data=df)
plt.title('Booking Status Distribution')
plt.xlabel('Booking Status')
plt.ylabel('Count')
plt.show()

# %%
# Pie chart - Distribution of booking status

status_counts = df['Booking_Status'].value_counts()
plt.figure(figsize=(8, 10))
plt.pie(status_counts, labels=status_counts.index, autopct='%.2f%%',  startangle=140)
plt.title('Distribution of Booking Status')
plt.show()

# %%
# to plot at what days the ride booking was successful

from datetime import datetime

df['day_of_week'] = df['Date'].dt.day_name()
df['day_of_week']
# Out:
# 0            Friday
# 1          Thursday
# 2           Tuesday
# 3            Monday
# 4           Tuesday
#             ...
# 103019    Wednesday
# 103020    Wednesday
# 103021    Wednesday
# 103022    Wednesday
# 103023    Wednesday
# Name: day_of_week, Length: 103024, dtype: object

# %%
# Group and count bookings by day
day_counts = df['day_of_week'].value_counts().reindex(['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
day_counts
# Out:
# day_of_week
# Monday       16729
# Tuesday      16926
# Wednesday    16434
# Thursday     13236
# Friday       13345
# Saturday     13341
# Sunday       13013
# Name: count, dtype: int64

# %%
# Plot
day_counts.plot(kind='line', marker='o')
plt.title('Bookings by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Bookings')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Payment Method Distribution
sns.countplot(x='Payment_Method', data=df)
plt.title('Payment Method Distribution')
plt.show()

# %%
# Vehicle Used for bookings Distribution

vehicle_counts = df['Vehicle_Type'].value_counts()
plt.figure(figsize=(8, 10))
plt.pie(vehicle_counts, labels=vehicle_counts.index, autopct='%.2f%%',  startangle=140)
plt.title('Distribution of Vehicle Status')
plt.show()

# %%
# Cancellation details and analysis



plt.figure(figsize=(8, 6))
sns.countplot(x='Canceled_Rides_by_Customer', data=df, palette='viridis')
plt.title('Canceled Rides by Customer')
plt.xlabel('Canceled Rides by Customer')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\gopir\AppData\Local\Temp\ipykernel_47952\998846357.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Canceled_Rides_by_Customer', data=df, palette='viridis')

# %%
#Standardized text data by converting to uppercase, formatted the date column, and removed irrelevant columns for 
# analysis.
df['Payment_Method'] = df['Payment_Method'].str.strip().str.upper()
df['Date'] = df['Date'].apply(lambda x: x.strftime('%Y-%m-%d') if pd.notnull(x) else None )
df.drop('Vehicle Images',axis=1,inplace=True)
df['Booking_Status'] = df['Booking_Status'].str.strip().str.upper()
df['Time'] = df['Time'].apply(lambda x: x.strftime('%H:%M:%S') if pd.notnull(x) else None )

# %%
# create SQL connection

import mysql.connector
connection = mysql.connector.connect (
    host =  "localhost",
    user = "root",
    password = "12345678"

)

cursor = connection.cursor()
cursor

# %%
# Create DB

query = 'create database ola'
cursor.execute(query)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\gopir\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'ola'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Create DB
#       3 query = 'create database ola'
# ...

# %%
import mysql.connector
connection = mysql.connector.connect (
    host =  "localhost",
    user = "root",
    password = "12345678",
    database = "ola"

)

cursor = connection.cursor()
cursor

# %%
query = 'drop table ola_rides'
cursor.execute(query)
connection.commit()

# %%
from sqlalchemy import create_engine
database_url = "mysql+mysqlconnector://root:12345678@localhost:3306/ola"
engine = create_engine(database_url)
df.to_sql(name='ola_rides', con=engine, index=True, index_label='id', if_exists='replace')
# Out:
# 103024

# %%
import mysql.connector
connection = mysql.connector.connect (
    host =  "localhost",
    user = "root",
    password = "12345678",
    database = "ola"

)

cursor = connection.cursor()
cursor

# %%
# 1. Retrieve all successful bookings:
import matplotlib.pyplot as plt

query = """ 
SELECT * 
FROM ola_rides 
WHERE Booking_Status = 'SUCCESS'
"""
cursor.execute(query)
results = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
succesful_bookings = pd.DataFrame(results,columns=columns)

# Convert 'Date' column to datetime if needed
succesful_bookings['Date'] = pd.to_datetime(succesful_bookings['Date'])

# Group by Date
daily_counts = succesful_bookings.groupby('Date').size()

# Plot
plt.figure(figsize=(12, 6))
daily_counts.plot(kind='line', marker='o', color='green')
plt.title("Successful Bookings Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Bookings")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 2. The average ride distance for each vehicle type:
query = """
SELECT Vehicle_Type, AVG(Ride_Distance) AS Avg_Ride_Distance
FROM ola_rides
WHERE Booking_Status = 'SUCCESS'
GROUP BY Vehicle_Type;
"""
cursor.execute(query)
results = cursor.fetchall()
for row in results:
    print(f"Vehicle Type: {row[0]}, Average Ride Distance: {row[1]:.2f} km")
# Out:
# Vehicle Type: Bike, Average Ride Distance: 24.93 km
# Vehicle Type: Prime SUV, Average Ride Distance: 24.88 km
# Vehicle Type: Mini, Average Ride Distance: 24.98 km
# Vehicle Type: Prime Plus, Average Ride Distance: 25.03 km
# Vehicle Type: Auto, Average Ride Distance: 10.04 km
# Vehicle Type: eBike, Average Ride Distance: 25.15 km
# Vehicle Type: Prime Sedan, Average Ride Distance: 25.01 km

# %%
#3. the total number of cancelled rides by customers:
query = """
SELECT COUNT(*) AS Total_Customer_Cancelled_Rides
FROM ola_rides
WHERE Canceled_Rides_by_Customer != 'Not Applicable';
"""
cursor.execute(query)
results = cursor.fetchone()
print("Total Cancelled Rides by Customers:", results[0])
# Out:
# Total Cancelled Rides by Customers: 10499

# %%
# 4. List the top 5 customers who booked the highest number of rides:
query = """
SELECT 
    TRIM(Customer_ID) AS CUSTOMERS,
    COUNT(*) AS TOTAL_RIDES
FROM ola_rides
WHERE Booking_Status = 'SUCCESS'
GROUP BY TRIM(Customer_ID)
ORDER BY TOTAL_RIDES DESC, TRIM(Customer_ID) ASC
LIMIT 5;
"""
cursor.execute(query)
results = cursor.fetchall()

for customer in results:
    print("Customer:", customer[0],"| Total Rides:",customer[1])
# Out:
# Customer: CID189965 | Total Rides: 4
# Customer: CID266327 | Total Rides: 4
# Customer: CID268274 | Total Rides: 4
# Customer: CID288207 | Total Rides: 4
# Customer: CID329193 | Total Rides: 4

# %%
top_customers = df[df['Booking_Status'] == 'SUCCESS']\
                    .groupby('Customer_ID')\
                    .size()\
                    .reset_index(name='Total_Rides')\
                    .sort_values(by=['Total_Rides', 'Customer_ID'], ascending=[False, True])\
                    .head(5)
top_customers
# Out:
#       Customer_ID  Total_Rides
# 5921    CID189965            4
# 11040   CID266327            4
# 11168   CID268274            4
# 12493   CID288207            4
# 15285   CID329193            4

# %%
# 5. Get the number of rides cancelled by drivers due to personal and car-related issues:
query = """
SELECT COUNT(*) AS Canceled_Rides_by_Driver
FROM ola_rides
WHERE Canceled_Rides_by_Driver = 'Personal & Car related issue';
"""
cursor.execute(query)
results = cursor.fetchone()
print("Total Cancelled Rides by drivers due to personal and car-related issues:", results[0])
# Out:
# Total Cancelled Rides by drivers due to personal and car-related issues: 6542

# %%
#6. Find the maximum and minimum driver ratings for Prime Sedan bookings:
query = """
SELECT 
    MAX(Driver_Ratings),
    MIN(Driver_Ratings)
FROM ola_rides
WHERE Vehicle_Type = 'Prime Sedan' AND Driver_Ratings >= 1
"""
cursor.execute(query)
results = cursor.fetchone()

print("The Maximum driver ratings for Prime Sedan Booking:", results[0]) 
print("The Minimum driver ratings for Prime Sedan Booking:", results[1])
# Out:
# The Maximum driver ratings for Prime Sedan Booking: 5.0
# The Minimum driver ratings for Prime Sedan Booking: 3.0

# %%
# 7. Retrieve all rides where payment was made using UPI:

query = """
SELECT *
FROM ola_rides
WHERE Payment_Method = 'UPI'
"""
cursor.execute(query)
results = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
upi_df = pd.DataFrame(results, columns=columns)

#converting 'Date' column to datetime 
upi_df['Date'] = pd.to_datetime(upi_df['Date'])
upi_trend = upi_df.groupby('Date').size()

plt.figure(figsize=(12, 6))
upi_trend.plot(kind='line', marker='o', color='purple')
plt.title("UPI Rides Over Time")
plt.xlabel("Date")
plt.ylabel("Number of UPI Bookings")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 8. Find the average customer rating per vehicle type:

query = """
SELECT Vehicle_Type, AVG(Customer_Rating)
FROM ola_rides
GROUP by Vehicle_Type
ORDER BY AVG(Customer_Rating)
"""

cursor.execute(query)
results= cursor.fetchall()
for row in results:
    print(f"The average customer rating for {row[0]} is {row[1]:2f}")
# Out:
# The average customer rating for eBike is 3.987854
# The average customer rating for Bike is 3.993376
# The average customer rating for Mini is 3.997731
# The average customer rating for Auto is 3.998811
# The average customer rating for Prime SUV is 3.999378
# The average customer rating for Prime Sedan is 4.001589
# The average customer rating for Prime Plus is 4.009499

# %%
# 9. Calculate the total booking value of rides completed successfully:
query ="""
SELECT SUM(Booking_Value)
FROM ola_rides
WHERE Booking_Status = 'SUCCESS'
"""
cursor.execute(query)
results = cursor.fetchone()
print(f"THe Total value of Successfull Bookings is ₹{results[0]:,.2f}")
# Out:
# THe Total value of Successfull Bookings is ₹35,080,467.00

# %%
# 10. List all incomplete rides along with the reason
query = """
SELECT Incomplete_Rides, Incomplete_Rides_Reason
FROM ola_rides
WHERE Incomplete_Rides = 'Yes'
"""
cursor.execute(query)
results = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
incomplete_ride = pd.DataFrame(results,columns=columns)

#Filter only incomplete rides with valid reasons
filtered_df = df[
    (df['Incomplete_Rides'] == 'Yes') & 
    (df['Incomplete_Rides_Reason'] != 'Not Applicable')
]

#Group by Vehicle_Type and Reason
grouped = filtered_df.groupby(['Vehicle_Type', 'Incomplete_Rides_Reason']).size().unstack(fill_value=0)

grouped.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='tab10')
plt.title("Incomplete Rides by Reason & Vehicle Type (Excl. 'Not Applicable')")
plt.xlabel("Vehicle Type")
plt.ylabel("Number of Rides")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
